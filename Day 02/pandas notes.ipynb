# %% [markdown]
# # Creating Reading and writing

# %%
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\python38\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import pandas as pd

# %% [markdown]
# # pandas consist of two type of objects
# #### 1. DataFrame
# #### 2. Series

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %%
df = pd.read_csv('winemag-data_first150k.csv')

# %%
df.shape
# Out:
# (150930, 11)

# %%
df.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
# 5           5   Spain  Deep, dense and pure from the opening bell, th...
# 6           6   Spain  Slightly gritty black-fruit aromas include a s...
# 7           7   Spain  Lush cedary black-fruit aromas are luxe and of...
# 8           8      US  This re-named vineyard was formerly bottled as...
# 9           9      US  The producer sources from two blocks of the vi...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0 country                                        description  \
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
#             designation  points  price            province           region_1  \
# 150925              NaN      91   20.0      Southern Italy  Fiano di Avellino
# 150926   Cuvée Prestige      91   27.0           Champagne          Champagne
# 150927    Terre di Dora      91   20.0      Southern Italy  Fiano di Avellino
# 150928  Grand Brut Rosé      90   52.0           Champagne          Champagne
# 150929              NaN      90   15.0  Northeastern Italy         Alto Adige
#
# ...

# %% [markdown]
# # Indexing selecting and assigning

# %%
df
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
df.country
# Out:
# 0             US
# 1          Spain
# 2             US
# 3             US
# 4         France
#            ...
# 150925     Italy
# 150926    France
# 150927     Italy
# 150928    France
# 150929     Italy
# Name: country, Length: 150930, dtype: object

# %%
df['country']
# Out:
# 0             US
# 1          Spain
# 2             US
# 3             US
# 4         France
#            ...
# 150925     Italy
# 150926    France
# 150927     Italy
# 150928    France
# 150929     Italy
# Name: country, Length: 150930, dtype: object

# %%
type(df['country'])
# Out:
# pandas.core.series.Series

# %%
df['country'][1]
# Out:
# 'Spain'

# %%
df.iloc[0]
# Out:
# Unnamed: 0                                                     0
# country                                                       US
# description    This tremendous 100% varietal wine hails from ...
# designation                                    Martha's Vineyard
# points                                                        96
# price                                                        235
# province                                              California
# region_1                                             Napa Valley
# region_2                                                    Napa
# variety                                       Cabernet Sauvignon
# winery                                                     Heitz
# Name: 0, dtype: object

# %%
df.iloc[:, 0]
# Out:
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 150925    150925
# 150926    150926
# 150927    150927
# 150928    150928
# 150929    150929
# Name: Unnamed: 0, Length: 150930, dtype: int64

# %%
df.iloc[:3, 0]
# Out:
# 0    0
# 1    1
# 2    2
# Name: Unnamed: 0, dtype: int64

# %%
df.iloc[[0, 1, 2], 0]
# Out:
# 0    0
# 1    1
# 2    2
# Name: Unnamed: 0, dtype: int64

# %%
df.iloc[-5:]
# Out:
#         Unnamed: 0 country                                        description  \
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
#             designation  points  price            province           region_1  \
# 150925              NaN      91   20.0      Southern Italy  Fiano di Avellino
# 150926   Cuvée Prestige      91   27.0           Champagne          Champagne
# 150927    Terre di Dora      91   20.0      Southern Italy  Fiano di Avellino
# 150928  Grand Brut Rosé      90   52.0           Champagne          Champagne
# 150929              NaN      90   15.0  Northeastern Italy         Alto Adige
#
# ...

# %%
df.loc[0, 'country']
# Out:
# 'US'

# %%
df.loc[:, ['country', 'description', 'designation']]
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation
# 0                          Martha's Vineyard
# 1       Carodorum Selección Especial Reserva
# ...

# %%
df.set_index("country") # it will not assign df instead it will return new df
# Out:
#          Unnamed: 0                                        description  \
# country
# US                0  This tremendous 100% varietal wine hails from ...
# Spain             1  Ripe aromas of fig, blackberry and cassis are ...
# US                2  Mac Watson honors the memory of a wine once ma...
# US                3  This spent 20 months in 30% new French oak, an...
# France            4  This is the top wine from La Bégude, named aft...
# ...             ...                                                ...
# Italy        150925  Many people feel Fiano represents southern Ita...
# France       150926  Offers an intriguing nose with ginger, lime an...
# Italy        150927  This classic example comes from a cru vineyard...
# France       150928  A perfect salmon shade, with scents of peaches...
# Italy        150929  More Pinot Grigios should taste like this. A r...
#
#                                   designation  points  price  \
# country
# ...

# %% [markdown]
# ## Conditional selection

# %%
df.country == 'Italy'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 150925     True
# 150926    False
# 150927     True
# 150928    False
# 150929     True
# Name: country, Length: 150930, dtype: bool

# %%
df.loc[df.country == 'Italy']
# Out:
#         Unnamed: 0 country                                        description  \
# 10              10   Italy  Elegance, complexity and structure come togeth...
# 32              32   Italy  Underbrush, scorched earth, menthol and plum s...
# 35              35   Italy  Forest floor, tilled soil, mature berry and a ...
# 37              37   Italy  Aromas of forest floor, violet, red berry and ...
# 38              38   Italy  This has a charming nose that boasts rose, vio...
# ...            ...     ...                                                ...
# 150920      150920   Italy  Rich and mature aromas of smoke, earth and her...
# 150922      150922   Italy  Made by 30-ish Roberta Borghese high above Man...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
df.loc[(df.country == 'Italy') & (df.points >= 90)]
# Out:
#         Unnamed: 0 country                                        description  \
# 10              10   Italy  Elegance, complexity and structure come togeth...
# 32              32   Italy  Underbrush, scorched earth, menthol and plum s...
# 35              35   Italy  Forest floor, tilled soil, mature berry and a ...
# 37              37   Italy  Aromas of forest floor, violet, red berry and ...
# 38              38   Italy  This has a charming nose that boasts rose, vio...
# ...            ...     ...                                                ...
# 150920      150920   Italy  Rich and mature aromas of smoke, earth and her...
# 150922      150922   Italy  Made by 30-ish Roberta Borghese high above Man...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
df.loc[(df.country == 'Italy') | (df.points >= 90)]
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
df.loc[df.country.isin(['Italy', 'France'])]
# Out:
#         Unnamed: 0 country                                        description  \
# 4                4  France  This is the top wine from La Bégude, named aft...
# 10              10   Italy  Elegance, complexity and structure come togeth...
# 13              13  France  This wine is in peak condition. The tannins an...
# 18              18  France  Coming from a seven-acre vineyard named after ...
# 32              32   Italy  Underbrush, scorched earth, menthol and plum s...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
df.loc[df.price.notnull()]
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %% [markdown]
# ## Assigning data

# %%
df['variety'] = 'whiteblend'

# %%
df
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
df.loc[0, 'country'] = 'india'

# %%
df
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0   india  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %% [markdown]
# ## summary Functions and Maps

# %%
df
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0   india  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
df.points.describe() # for columns having number
# Out:
# count    150930.000000
# mean         87.888418
# std           3.222392
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          90.000000
# max         100.000000
# Name: points, dtype: float64

# %%
df.winery.describe() # for columns having strings
# Out:
# count              150930
# unique              14810
# top       Williams Selyem
# freq                  374
# Name: winery, dtype: object

# %%
df.points.max()
df.points.count()
df.points.std()
df.points.mean()
# Out:
# 87.8884184721394

# %%
print(df.winery.count())
print(df.winery.unique())
print(df.winery.value_counts())
# Out:
# 150930
# ['Heitz' 'Bodega Carmen Rodríguez' 'Macauley' ... 'Screwed' 'Red Bucket'
#  'White Knot']
# Williams Selyem             374
# Testarossa                  274
# DFJ Vinhos                  258
# Chateau Ste. Michelle       225
# Columbia Crest              217
#                            ...
# Mademoiselle Comédie          1
# Domaine St Martin d'Agel      1
# The Loop                      1
# Pugilist                      1
# Conarium                      1
# Name: winery, Length: 14810, dtype: int64

# %% [markdown]
# ### Maps

# %%
df = pd.read_csv('winemag-data_first150k.csv')
mean_value = df.points.mean()
df.points.map(lambda p: p - mean_value) #The function you pass to map() should expect a single value from the Series
# Out:
# 0         8.111582
# 1         8.111582
# 2         8.111582
# 3         8.111582
# 4         7.111582
#             ...
# 150925    3.111582
# 150926    3.111582
# 150927    3.111582
# 150928    2.111582
# 150929    2.111582
# Name: points, Length: 150930, dtype: float64

# %%
df = pd.read_csv('winemag-data_first150k.csv')
def remean_points(row):
    row.points = row.points - mean_value
    return row
df.apply(remean_points, axis='columns') ## apply() is the equivalent method if we want to transform a whole DataFrame by calling a custom method on each row.
# If we had called reviews.apply() with axis='index', then instead of passing a function to transform each row, we would need to give a function to transform each column.
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %% [markdown]
# ## datatypes and missing values

# %%
df.price.dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# country         object
# description     object
# designation     object
# points           int64
# price          float64
# province        object
# region_1        object
# region_2        object
# variety         object
# winery          object
# dtype: object

# %%
df.points.astype('float64')
# Out:
# 0         96.0
# 1         96.0
# 2         96.0
# 3         96.0
# 4         95.0
#           ...
# 150925    91.0
# 150926    91.0
# 150927    91.0
# 150928    90.0
# 150929    90.0
# Name: points, Length: 150930, dtype: float64

# %% [markdown]
# ### missing values

# %%
pd.isnull(df.country)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 150925    False
# 150926    False
# 150927    False
# 150928    False
# 150929    False
# Name: country, Length: 150930, dtype: bool

# %%
df[pd.isnull(df.country)]
# Out:
#         Unnamed: 0 country                                        description  \
# 1133          1133     NaN  Delicate white flowers and a spin of lemon pee...
# 1440          1440     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 68226        68226     NaN  From first sniff to last, the nose never makes...
# 113016      113016     NaN  From first sniff to last, the nose never makes...
# 135696      135696     NaN  From first sniff to last, the nose never makes...
#
#          designation  points  price province region_1 region_2     variety  \
# 1133       Askitikos      90   17.0      NaN      NaN      NaN   Assyrtiko
# 1440            Shah      90   30.0      NaN      NaN      NaN   Red Blend
# 68226   Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 113016  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 135696  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
#
#            winery
# 1133     Tsililis
# ...

# %%
df.province.fillna("Unknown")
# Out:
# 0                 California
# 1             Northern Spain
# 2                 California
# 3                     Oregon
# 4                   Provence
#                  ...
# 150925        Southern Italy
# 150926             Champagne
# 150927        Southern Italy
# 150928             Champagne
# 150929    Northeastern Italy
# Name: province, Length: 150930, dtype: object

# %%
df[pd.isnull(df.province)]
# Out:
#         Unnamed: 0 country                                        description  \
# 1133          1133     NaN  Delicate white flowers and a spin of lemon pee...
# 1440          1440     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 68226        68226     NaN  From first sniff to last, the nose never makes...
# 113016      113016     NaN  From first sniff to last, the nose never makes...
# 135696      135696     NaN  From first sniff to last, the nose never makes...
#
#          designation  points  price province region_1 region_2     variety  \
# 1133       Askitikos      90   17.0      NaN      NaN      NaN   Assyrtiko
# 1440            Shah      90   30.0      NaN      NaN      NaN   Red Blend
# 68226   Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 113016  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 135696  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
#
#            winery
# 1133     Tsililis
# ...

# %%
pd.isnull(df.province).value_counts()
# Out:
# False    150925
# True          5
# Name: province, dtype: int64

# %%
df
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
df.province.replace("California", "cal")
# Out:
# 0                        cal
# 1             Northern Spain
# 2                        cal
# 3                     Oregon
# 4                   Provence
#                  ...
# 150925        Southern Italy
# 150926             Champagne
# 150927        Southern Italy
# 150928             Champagne
# 150929    Northeastern Italy
# Name: province, Length: 150930, dtype: object

# %% [markdown]
# ## Renaming column names

# %%
df
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
df.rename(columns={'province': 'locality'})
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...
